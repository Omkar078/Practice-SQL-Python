# %%
import pandas as pd
import os
import glob

# %%
folder_path = '100k_synthea_covid19_csv'
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# %% [markdown]
# ## Reading the CSVS and storing each into df

# %%
older_path = "100k_synthea_covid19_csv"

csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

dataframes = {}

for file in csv_files:
    file_name = os.path.splitext(os.path.basename(file))[0]
    dataframes[file_name] = pd.read_csv(file)

print(dataframes.keys())
# Out:
# dict_keys(['allergies', 'careplans', 'conditions', 'devices', 'encounters', 'imaging_studies', 'immunizations', 'medications', 'observations', 'organizations', 'patients', 'payers', 'payer_transitions', 'procedures', 'providers', 'supplies'])

# %%
#### Counting the rows of each df
for name, df in dataframes.items():
    print(name, len(df))
# Out:
# allergies 51592
# careplans 377726
# conditions 1143900
# devices 23694
# encounters 3188675
# imaging_studies 45609
# immunizations 168160
# medications 4227723
# observations 16219969
# organizations 9175
# patients 124150
# payers 10
# payer_transitions 409553
# procedures 979564
# providers 60534
# supplies 1389858
